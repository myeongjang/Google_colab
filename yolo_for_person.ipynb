# %% [markdown]
# <a href="https://colab.research.google.com/github/myeongjang/Google_colab/blob/master/yolo_for_person.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !history

# %%
# !pip install pydrive

# !pip install Cython 
# !pip install pytube
# !pip install PyDrive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Collecting pydrive
#   Downloading https://files.pythonhosted.org/packages/52/e0/0e64788e5dd58ce2d6934549676243dc69d982f198524be9b99e9c2a4fd5/PyDrive-1.3.1.tar.gz (987kB)
#     100% |████████████████████████████████| 993kB 20.0MB/s
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from pydrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (3.13)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (0.11.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (3.0.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (1.11.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.2.3)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.4.5)
# Building wheels for collected packages: pydrive
# done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built pydrive
# Installing collected packages: pydrive
# Successfully installed pydrive-1.3.1
# Requirement already satisfied: Cython in /usr/local/lib/python3.6/dist-packages (0.29.2)
# Collecting pytube
#   Downloading https://files.pythonhosted.org/packages/af/56/c9b484e93e1f3a4ef6aefbc1e68258121831007938556daf968ab4519c9c/pytube-9.3.5-py3-none-any.whl
# Installing collected packages: pytube
# Successfully installed pytube-9.3.5
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (1.11.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.3)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.11.3)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.5)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# darknet  gdrive  sample_data

# %%
# %cd /content/gdrive/My Drive

# !cp -rf darkflow-master /content/
# Out:
# /content/gdrive/My Drive

# %%
# %cd /content/
# !mv darkflow-master darkflow 
# !ls
# Out:
# /content
# darkflow  gdrive  sample_data

# %%
# %cd /content/darkflow
# !pip install -e .
# Out:
# /content/darkflow
# Obtaining file:///content/darkflow
# Installing collected packages: darkflow
#   Running setup.py develop for darkflow
# Successfully installed darkflow

# %%
import os
import time
from tqdm import tqdm

# %%
newpath = '/content/darkflow/bin'
if not os.path.exists(newpath):
  os.makedirs(newpath)
# %cd /content/darkflow/bin
#!wget https://pjreddie.com/media/files/yolov2-tiny-voc.weights
# Out:
# /content/darkflow/bin

# %%
# !wget https://pjreddie.com/media/files/yolov2.weights
# Out:
# --2019-01-08 11:55:06--  https://pjreddie.com/media/files/yolov2.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203934260 (194M) [application/octet-stream]
# Saving to: ‘yolov2.weights’
#
# yolov2.weights      100%[===================>] 194.49M  63.9MB/s    in 3.0s
#
# 2019-01-08 11:55:09 (63.9 MB/s) - ‘yolov2.weights’ saved [203934260/203934260]

# %%
# !ls
# Out:
# yolov2.weights

# %%
#!mv yolov2-tiny-voc.weights tiny-yolo-voc.weights

# %%
# %cd /content/darkflow
# !ls
# Out:
# /content/darkflow
# bin    _coveragerc	  demo.gif    labels.txt   README.md   test
# build  darkflow		  flow	      LICENSE	   sample_img  _travis.yml
# cfg    darkflow.egg-info  _gitignore  preview.png  setup.py

# %%
# %cd /content/darkflow
# !ls
# Out:
# /content/darkflow
# bin    darkflow		  demo.gif    LICENSE	   sample_img
# build  darkflow.egg-info  flow	      preview.png  setup.py
# cfg    darkflow-master	  labels.txt  README.md    test

# %%
from darkflow.net.build import TFNet
import cv2
import matplotlib.pyplot as plt

# %%
#flow --model cfg/tiny-yolo-voc-1c.cfg --load bin/tiny-yolo-voc.weights --demo your_video.mp4 --labels labels.txt

# %%
options = {
    'model': 'cfg/yolo.cfg',
    'load': 'bin/yolov2.weights',
    'threshold': 0.1,
    'gpu' : 1.0
          }

# %%
# Out:
# /content/darkflow-master

# %%
tfnet = TFNet(options)
# Out:
# /content/darkflow/darkflow/dark/darknet.py:54: UserWarning: ./cfg/yolov2.cfg not found, use cfg/yolo.cfg instead
#   cfg_path, FLAGS.model))
# Parsing cfg/yolo.cfg
# Loading bin/yolov2.weights ...
# Successfully identified 203934260 bytes
# Finished in 0.03151965141296387s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 608, 608, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 608, 608, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 304, 304, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 304, 304, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 76, 76, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 76, 76, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | concat [16]                      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 64)
#  Load  |  Yep!  | local flatten 2x2                | (?, 19, 19, 256)
#  Load  |  Yep!  | concat [27, 24]                  | (?, 19, 19, 1280)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1    linear           | (?, 19, 19, 425)
# -------+--------+----------------------------------+---------------
# GPU mode with 1.0 usage
# Finished in 6.169331789016724s

# %%
def predict_img(link):
  
  result = tfnet.return_predict(link)
   

  for n,value in enumerate(result):
    
    tl = (result[n]['topleft']['x'], result[n]['topleft']['y'])
    br = (result[n]['bottomright']['x'], result[n]['bottomright']['y'])
    label = result[n]['label']
    img = cv2.rectangle(img,tl,br,(0,255,0))
    
  plt.figure(figsize=(20,10))    
  plt.imshow(img)

# %%
def create_image_paths():
  
  import glob
  # Get all image file paths to a list.
  images = list(glob.iglob(os.path.join('/content/sample_data_frames/',title, '*.*')))
  # Sort the images by name index.
  images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))
  
  return images

# %%
def download_youtube_video(link):
  
  
  from pytube import YouTube
  yt = YouTube(link)
  streams = yt.streams.get_by_itag('18')
  streams.download('/content/sample_data')
  title = streams.default_filename
  
  print('Youtube Video Downloaded...')
  return  title

# %%
def fps():
  
  
  video = cv2.VideoCapture(os.path.join('/content/sample_data/',title))  
  fps = video.get(cv2.CAP_PROP_FPS)
  print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))
  video.release()
  return fps

# %%
def make_video(outvid, images=None, fps=30, size=None,
               is_color=True, format="FMP4"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    @param      format      see http://www.fourcc.org/codecs.php
    @return                 see http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_video_display/py_video_display.html
    """
    from tqdm import tqdm
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in tqdm(images):
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid


  

#outvid = os.path.join(Result ,"out.mp4")
#make_video('/content/sample_data/video_out.mp4', images, fps=30)

# %%
def sample_frames():
  
  capture = cv2.VideoCapture(os.path.join('/content/sample_data/',title)) 

  
  frames = []
  frame_count = 0

  video_frame_path = os.path.join('/content/sample_data_frames/',title)
  
  if not os.path.exists(video_frame_path):
    os.makedirs(video_frame_path)
    print('Frames Directory Created...')
  
  while True:
  
    ret, frame = capture.read()
    frames.append(frame)
    frame_count += 1
    
  
  
    if not ret:
      print(frame_count)
      return (frames,frame_count,video_frame_path)
      break

# %%
def predict_video(link):
  
  global title
  
  title = download_youtube_video(link)
   
  frames,frame_count,video_frame_path = sample_frames()
  
  #load video and get every frame of it for analysis..
  

  
  # for every frame run yolo prediction and save the frame as jpg file

  for count,frame in tqdm(enumerate(frames[1:-10])):
    

    frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    
    results = tfnet.return_predict(frame)
  
    for n,value in enumerate(results):
      
      tl = (results[n]['topleft']['x'], results[n]['topleft']['y'])
      br = (results[n]['bottomright']['x'], results[n]['bottomright']['y'])
      label = results[n]['label']
      frame = cv2.rectangle(frame,tl,br,(0,255,0),3)
      frame = cv2.putText(frame,label,tl,cv2.FONT_HERSHEY_COMPLEX,1,(0,0,0),2)
      
      #frame = cv2.addText(label)
      #frame = cv2.line(img,(0,frame.shape[0]//2),(600,img.shape[0]//2),(255,0,0),2)   
      
  
    name = '{0}.jpg'.format(count)
    
    name = os.path.join(video_frame_path,name)  
    cv2.imwrite(name, frame)
    
  print('All Frames Saved...')
  
  newpath = '/content/sample_data_out/'
  if not os.path.exists(newpath):
    os.makedirs(newpath)
    
  images = create_image_paths()
  print(images)
  frames_per_second = fps()
  make_video(os.path.join('/content/sample_data_out/',title), images, fps=frames_per_second)

# %%
predict_video('https://www.youtube.com/watch?v=XXBDmZRXfhw')
# Out:
# Youtube Video Downloaded...
# Frames Directory Created...
# 0it [00:00, ?it/s]
# 2463
# 2452it [1:02:56,  1.54s/it]
#   1%|          | 13/2452 [00:00<00:18, 129.58it/s]
# All Frames Saved...
# ['/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/0.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/1.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/2.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/3.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/4.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/5.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/6.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/7.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/8.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/9.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/10.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/11.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/12.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/13.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/14.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/15.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/16.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/17.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/18.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/19.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/20.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/21.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/22.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/23.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/24.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/25.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/26.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/27.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/28.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/29.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/30.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/31.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/32.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/33.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/34.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/35.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/36.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/37.jpg', '/content/sample_data_frames/TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4/38.jpg', '/content/sample_data_frames/TO ...
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 25.0
# 100%|██████████| 2452/2452 [00:14<00:00, 166.47it/s]

# %%
# %cd /content/sample_data_out
# !ls
# Out:
# /content/sample_data_out
# 'TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4'

# %%
# !mv 'TOP 5 WINS Compilation - pt1  Meanwhile in Russia 2015  MIR.mp4' /content/gdrive/'My Drive'

# %%
# %cd 'My Drive'
# Out:
# /content/gdrive/My Drive

# %%
# Out:
#  쿠바
#  파이썬
#  0.ITstudy
#  1808.00408.pdf
#  1808.07757.pdf
# '스캔 18년 4월 20일 (1).pdf'
# '스캔 18년 4월 20일.pdf'
# '조명장 (A반).gdoc'
#  annotations_trainval2017.zip
#  assignment13.py
#  BeautifulSoup.pyc
#  Brochure.gdoc
#  centos7_sample.zip
#  Classroom
# 'Colab Notebooks'
# '입문후반 [Day 01] 쉐도잉 훈련 10문장 음원.mp3'
# '부교재 음원 [Day 01] 의문사 의문문1 추가 연습문제.mp3'
#  dictionary9.py
#  Encore
# 'Encore download file.zip'
#  epp500_0651_64bit.exe
#  eticket.pdf
#  geodata.sqlite
# 'How to use GIt and Github.gdoc'
#  후원내역서.html
# 'icml_2018 (1).pdf'
#  icml_2018.pdf
# '[Johns오픽] 기본 스튜디오 (2)'
#  mbox-short.txt
#  쿠바.mp4
#  서커스단.MP4
#  opic
#  OracleXE112_Win64.zip
#  org.sqlite
#  panoptic_annotations_trainval2017.zip
#  README.txt
#  regex_sum_174257.txt
#  regex_sum_42.txt
# ' Result'
#  resume.docx
#  resume.docx.gdoc
#  Resume.gdoc
# '이력서_Rev(수정).docx'
#  romeo.txt
#  roster_data.json
#  rosterdb.sqlite
#  연습용SQL문제들.zip
#  stuff_annotations_trainval2017.zip
#  tableau_data.zip
#  test2017.zip
#  서커스단.THM
#  train2017.zip
#  where.data
#  where.html
#  where.js
#  words.txt
# 'yolov2 (1).weights'
#  yolov2.weights
